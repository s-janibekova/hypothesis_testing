# %%
mean = 395 
# 0.84% have income more than 429.35 
# standatd deviation ? 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import math

# %% [markdown]
# 1 ) Using the teacher's rating data, is there an association between native (native English speakers) and the number of credits taught? What test will you use?

# %% [markdown]
# Double-click **here** for solution
#
# <!-- Chi-Squared Test for Accociation -->

# %% [markdown]
# 2)
# If I wanted to test for association using chi-square test, whether there is an association between gender (Male or Female) and tenure-ship (tenured or not tenured), what will be my degree of freedom?

# %% [markdown]
# Double-click **here** for solution
#
# <!--  1 -->

# %% [markdown]
# 3) Consider a normally distributed data set with mean μ = 63.18 inches and standard deviation σ= 13.27 inches. What is the z-score when x = 91.54 inches? (To 3 decimal places)

# %% [markdown]
# Double-click **here** for solution
#
# <!--  2.137  -->

# %% [markdown]
# ![image.png](attachment:8bf032e1-8361-451f-822f-feb08b2d0c93.png)![image.png](attachment:08c426da-a7e5-4b55-a897-1fd2e6ba0484.png)
# Battery life of smartphones is of great concern to customers. A consumer group tested four brands of smartphones to determine the battery life. Samples of phones of each brand were fully charged and left to run until the battery died. The table above displays the number of hours each of the batteries lasted. What test will be be using to test the difference in means?

# %% [markdown]
# Double-click **here** for solution
#
# <!--  ANOVA  -->

# %% [markdown]
# 5) The mineral content of a particular brand of  supplement pills is normally distributed with mean 490 mg and variance of 400. What is the probability that a randomly selected pill contains at least 500 mg of minerals?

# %%
1 - scipy.stats.norm.cdf(500, loc=490, scale = 20)
# Out:
# 0.3085375387259869

# %% [markdown]
# 6) The average hourly wage at a fast-food restaurant is 5.85 with a standard deviation of 0.35. Assume that the wages are normally distributed. The probability that a selected worker earns more than $6.90 is

# %%
1 - scipy.stats.norm.cdf(6.90, loc=5.85, scale=0.35)
# Out:
# 0.0013498980316301035

# %%
# scipy.stats.ttest_ind(a, b, equal_var=True) just additional task

# %%
# (91.54 - 63.18) / 13.27

# %%
# scipy.stats.norm.cdf()

# %% [markdown]
# 7) The time X taken by a cashier in a grocery store express lane to complete a transaction follows a normal distribution with mean 90 seconds and standard deviation 20 seconds.What is the first quartile of the distribution of X (in seconds)?

# %%
a = scipy.stats.norm.rvs(loc=90, scale=20,size =2000, random_state=None)
np.percentile(a, 25)
# Out:
# 76.60005334407467
